# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Read the CSV and Inspect the Data

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %%
# Check dataframe for any null or non numeric feature values pre clean
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68817 entries, 0 to 68816
# Data columns (total 86 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   loan_amnt                   68817 non-null  float64
#  1   int_rate                    68817 non-null  float64
#  2   installment                 68817 non-null  float64
#  3   home_ownership              68817 non-null  object
#  4   annual_inc                  68817 non-null  float64
#  5   verification_status         68817 non-null  object
#  6   issue_d                     68817 non-null  object
#  7   loan_status                 68817 non-null  object
#  8   pymnt_plan                  68817 non-null  object
#  9   dti                         68817 non-null  float64
#  10  delinq_2yrs                 68817 non-null  float64
#  11  inq_last_6mths              68817 non-null  float64
#  12  open_acc                    68817 non-null  float64
#  13  pub_rec                     68817 non-null  float64
#  14  revol_bal                   68817 non-null  float64
#  15  total_acc                   68817 non-null  float64
#  16  initial_list_status         68817 non-null  object
#  17  out_prncp                   68817 non-null  float64
#  18  out_prncp_inv               68817 non-null  float64
#  19  total_pymnt                 68817 non-null  float64
#  20  total_pymnt_inv             68817 non-null  float64
#  21  total_rec_prncp             68817 non-null  float64
#  22  total_rec_int               68817 non-null  float64
#  23  total_rec_late_fee          68817 non-null  float64
#  24  recoveries                  68817 non-null  float64
#  25  collection_recovery_fee     68817 non-null  float64
#  26  last_pymnt_amnt             68817 non-null  float64
#  27  next_pymnt_d                68817 non-null  object
#  28  collections_12_mths_ex_med  68817 non-null  float64
#  29  policy_code                 68817 non-null  float64
#  30  application_type            68817 non-null  object
#  31  acc_now_delinq              68817 non-null  float64
#  32  tot_coll_amt                68817 non-null  float64
#  33  tot_cur_bal                 68817 non-null  float64
#  34  open_acc_6m                 68817 non-null  float64
#  35  open_act_il                 68817 non-null  float64
#  36  open_il_12m                 68817 non-null  float64
#  37  open_il_24m                 68817 non-null  float64
#  38  mths_since_rcnt_il          68817 non-null  float64
#  39  total_bal_il                68817 non-null  float64
#  40  il_util                     68817 non-null  float64
#  41  open_rv_12m                 68817 non-null  float64
#  42  open_rv_24m                 68817 non-null  float64
#  43  max_bal_bc                  68817 non-null  float64
#  44  all_util                    68817 non-null  float64
#  45  total_rev_hi_lim            68817 non-null  float64
#  46  inq_fi                      68817 non-null  float64
#  47  total_cu_tl                 68817 non-null  float64
#  48  inq_last_12m                68817 non-null  float64
#  49  acc_open_past_24mths        68817 non-null  float64
#  50  avg_cur_bal                 68817 non-null  float64
#  51  bc_open_to_buy              68817 non-null  float64
#  52  bc_util                     68817 non-null  float64
#  53  chargeoff_within_12_mths    68817 non-null  float64
#  54  delinq_amnt                 68817 non-null  float64
#  55  mo_sin_old_il_acct          68817 non-null  float64
#  56  mo_sin_old_rev_tl_op        68817 non-null  float64
#  57  mo_sin_rcnt_rev_tl_op       68817 non-null  float64
#  58  mo_sin_rcnt_tl              68817 non-null  float64
#  59  mort_acc                    68817 non-null  float64
#  60  mths_since_recent_bc        68817 non-null  float64
#  61  mths_since_recent_inq       68817 non-null  float64
#  62  num_accts_ever_120_pd       68817 non-null  float64
#  63  num_actv_bc_tl              68817 non-null  float64
#  64  num_actv_rev_tl             68817 non-null  float64
#  65  num_bc_sats                 68817 non-null  float64
#  66  num_bc_tl                   68817 non-null  float64
#  67  num_il_tl                   68817 non-null  float64
#  68  num_op_rev_tl               68817 non-null  float64
#  69  num_rev_accts               68817 non-null  float64
#  70  num_rev_tl_bal_gt_0         68817 non-null  float64
#  71  num_sats                    68817 non-null  float64
#  72  num_tl_120dpd_2m            68817 non-null  float64
#  73  num_tl_30dpd                68817 non-null  float64
#  74  num_tl_90g_dpd_24m          68817 non-null  float64
#  75  num_tl_op_past_12m          68817 non-null  float64
#  76  pct_tl_nvr_dlq              68817 non-null  float64
#  77  percent_bc_gt_75            68817 non-null  float64
#  78  pub_rec_bankruptcies        68817 non-null  float64
#  79  tax_liens                   68817 non-null  float64
#  80  tot_hi_cred_lim             68817 non-null  float64
#  81  total_bal_ex_mort           68817 non-null  float64
#  82  total_bc_limit              68817 non-null  float64
#  83  total_il_high_credit_limit  68817 non-null  float64
#  84  hardship_flag               68817 non-null  object
#  85  debt_settlement_flag        68817 non-null  object
# dtypes: float64(76), object(10)
# memory usage: 45.2+ MB

# %%
# Identify any non numeric feature value columns that need to be treated
# Examine this feature data to determin the appropriate mehtods for cleaning
df.select_dtypes(include='object')
# Out:
#       home_ownership verification_status   issue_d loan_status pymnt_plan  \
# 0               RENT     Source Verified  Mar-2019    low_risk          n
# 1           MORTGAGE            Verified  Mar-2019    low_risk          n
# 2           MORTGAGE            Verified  Mar-2019    low_risk          n
# 3               RENT            Verified  Mar-2019    low_risk          n
# 4           MORTGAGE        Not Verified  Mar-2019    low_risk          n
# ...              ...                 ...       ...         ...        ...
# 68812           RENT     Source Verified  Jan-2019    low_risk          n
# 68813           RENT        Not Verified  Jan-2019    low_risk          n
# 68814       MORTGAGE     Source Verified  Jan-2019    low_risk          n
# 68815       MORTGAGE            Verified  Jan-2019    low_risk          n
# 68816       MORTGAGE            Verified  Jan-2019    low_risk          n
#
#       initial_list_status next_pymnt_d application_type hardship_flag  \
# 0                       w     May-2019       Individual             N
# 1                       w     May-2019       Individual             N
# 2                       w     May-2019       Individual             N
# 3                       w     May-2019       Individual             N
# 4                       w     May-2019       Individual             N
# ...                   ...          ...              ...           ...
# 68812                   w     May-2019       Individual             N
# 68813                   w     May-2019       Individual             N
# 68814                   w     May-2019       Individual             N
# 68815                   f     May-2019       Individual             N
# 68816                   w     May-2019       Individual             N
#
#       debt_settlement_flag
# 0                        N
# 1                        N
# 2                        N
# 3                        N
# 4                        N
# ...                    ...
# 68812                    N
# 68813                    N
# 68814                    N
# 68815                    N
# 68816                    N
#
# [68817 rows x 10 columns]

# %%
# Return columns from dataframe for any null or non numeric feature values pre clean
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68817 entries, 0 to 68816
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   home_ownership        68817 non-null  object
#  1   verification_status   68817 non-null  object
#  2   issue_d               68817 non-null  object
#  3   loan_status           68817 non-null  object
#  4   pymnt_plan            68817 non-null  object
#  5   initial_list_status   68817 non-null  object
#  6   next_pymnt_d          68817 non-null  object
#  7   application_type      68817 non-null  object
#  8   hardship_flag         68817 non-null  object
#  9   debt_settlement_flag  68817 non-null  object
# dtypes: object(10)
# memory usage: 5.3+ MB

# %% [markdown]
# ### Data Inspection Assessment
#
# It can be seen when examining this data that there are 9 feature data columns (other than our targe column **loan_status**) that contain objects that need to be treated.
#
# At this stage it is noted other than incompatible Dtypes for modelling there are no null rows, values or other basic data integrity issues

# %% [markdown]
# ## Perform Initial Data Cleaning
#
# The feature data will be cleaned and treated using date splitting and conversion along with integer encoding. Before progressing to data set splitting and scaling

# %%
# Split and treat the no numeric data in the issue_d and next_pymnt_d columns
# Split year from Month short name into two new columns for issue_d column
df[['issue_month','issue_year']] = df['issue_d'].str.split('-', expand=True)
# Split year from Month short name into two new columns for next_pymnt_d column
df[['next_pymnt_month','next_pymnt_year']] = df['next_pymnt_d'].str.split('-', expand=True)

# Create Months dictionary using month shortname as seen in the data
months_num = {
    "Jan": 1,
    "Feb": 2,
    "Mar": 3,
    "Apr": 4,
    "May": 5,
    "Jun": 6,
    "Jul": 7,
    "Aug": 8,
    "Sep": 9,
    "Oct": 10,
    "Nov": 11,
    "Dec": 12,
}

# Months' names encoded using the dictionary values
df["issue_month_num"] = df["issue_month"].apply(lambda x: months_num[x])
df["next_pymnt_month_num"] = df["next_pymnt_month"].apply(lambda x: months_num[x])

# Convert issue_year and next_pymnt_year column to int data type
df = df.astype({"issue_year": int,"next_pymnt_year": int})

# Drop the date columns as this data has been treated and numerically represented in new columns
df.drop(["issue_d", "issue_month","next_pymnt_d", "next_pymnt_month"], axis=1, inplace=True)

# Create list of all remaining columns that need to be treated by integer encoder
non_integer_columns =  ["home_ownership", "verification_status", "pymnt_plan", "initial_list_status", "application_type", "hardship_flag", "debt_settlement_flag"]  

#Create loop to integer encode the remaining data 
for column in non_integer_columns:
    # Creating an instance of label encoder for integer encoding the columns data
    label_encoder = LabelEncoder()
    # Fitting the label encoder
    label_encoder.fit(df[column])
    # Encode the data as an integer into new label encoded column
    encoded_column_name = column + "_le"
    df[encoded_column_name] = label_encoder.transform(df[column]) 
    # Drop the source column
    df.drop([column], axis=1, inplace=True)

# Inspect the cleaned data    
df.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc loan_status    dti  \
# 0    10500.0    0.1719       375.35     66000.0    low_risk  27.24
# 1    25000.0    0.2000       929.09    105000.0    low_risk  20.23
# 2    20000.0    0.2000       529.88     56000.0    low_risk  24.26
# 3    10000.0    0.1640       353.55     92000.0    low_risk  31.44
# 4    22000.0    0.1474       520.39     52000.0    low_risk  18.76
#
#    delinq_2yrs  inq_last_6mths  open_acc  pub_rec  ...  next_pymnt_year  \
# 0          0.0             0.0       8.0      0.0  ...             2019
# 1          0.0             0.0      17.0      1.0  ...             2019
# 2          0.0             0.0       8.0      0.0  ...             2019
# 3          0.0             1.0      10.0      1.0  ...             2019
# 4          0.0             1.0      14.0      0.0  ...             2019
#
#    issue_month_num  next_pymnt_month_num  home_ownership_le  \
# 0                3                     5                  3
# 1                3                     5                  1
# 2                3                     5                  1
# 3                3                     5                  3
# 4                3                     5                  1
#
#    verification_status_le  pymnt_plan_le  initial_list_status_le  \
# 0                       1              0                       1
# 1                       2              0                       1
# 2                       2              0                       1
# 3                       2              0                       1
# 4                       0              0                       1
#
#    application_type_le  hardship_flag_le  debt_settlement_flag_le
# 0                    0                 0                        0
# 1                    0                 0                        0
# 2                    0                 0                        0
# 3                    0                 0                        0
# 4                    0                 0                        0
#
# [5 rows x 88 columns]

# %%
# Return columns from dataframe for any null or non numeric feature values pre clean
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68817 entries, 0 to 68816
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   loan_status  68817 non-null  object
# dtypes: object(1)
# memory usage: 537.8+ KB

# %%
# Check dataframe for any null or non numeric feature values post clean
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68817 entries, 0 to 68816
# Data columns (total 88 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   loan_amnt                   68817 non-null  float64
#  1   int_rate                    68817 non-null  float64
#  2   installment                 68817 non-null  float64
#  3   annual_inc                  68817 non-null  float64
#  4   loan_status                 68817 non-null  object
#  5   dti                         68817 non-null  float64
#  6   delinq_2yrs                 68817 non-null  float64
#  7   inq_last_6mths              68817 non-null  float64
#  8   open_acc                    68817 non-null  float64
#  9   pub_rec                     68817 non-null  float64
#  10  revol_bal                   68817 non-null  float64
#  11  total_acc                   68817 non-null  float64
#  12  out_prncp                   68817 non-null  float64
#  13  out_prncp_inv               68817 non-null  float64
#  14  total_pymnt                 68817 non-null  float64
#  15  total_pymnt_inv             68817 non-null  float64
#  16  total_rec_prncp             68817 non-null  float64
#  17  total_rec_int               68817 non-null  float64
#  18  total_rec_late_fee          68817 non-null  float64
#  19  recoveries                  68817 non-null  float64
#  20  collection_recovery_fee     68817 non-null  float64
#  21  last_pymnt_amnt             68817 non-null  float64
#  22  collections_12_mths_ex_med  68817 non-null  float64
#  23  policy_code                 68817 non-null  float64
#  24  acc_now_delinq              68817 non-null  float64
#  25  tot_coll_amt                68817 non-null  float64
#  26  tot_cur_bal                 68817 non-null  float64
#  27  open_acc_6m                 68817 non-null  float64
#  28  open_act_il                 68817 non-null  float64
#  29  open_il_12m                 68817 non-null  float64
#  30  open_il_24m                 68817 non-null  float64
#  31  mths_since_rcnt_il          68817 non-null  float64
#  32  total_bal_il                68817 non-null  float64
#  33  il_util                     68817 non-null  float64
#  34  open_rv_12m                 68817 non-null  float64
#  35  open_rv_24m                 68817 non-null  float64
#  36  max_bal_bc                  68817 non-null  float64
#  37  all_util                    68817 non-null  float64
#  38  total_rev_hi_lim            68817 non-null  float64
#  39  inq_fi                      68817 non-null  float64
#  40  total_cu_tl                 68817 non-null  float64
#  41  inq_last_12m                68817 non-null  float64
#  42  acc_open_past_24mths        68817 non-null  float64
#  43  avg_cur_bal                 68817 non-null  float64
#  44  bc_open_to_buy              68817 non-null  float64
#  45  bc_util                     68817 non-null  float64
#  46  chargeoff_within_12_mths    68817 non-null  float64
#  47  delinq_amnt                 68817 non-null  float64
#  48  mo_sin_old_il_acct          68817 non-null  float64
#  49  mo_sin_old_rev_tl_op        68817 non-null  float64
#  50  mo_sin_rcnt_rev_tl_op       68817 non-null  float64
#  51  mo_sin_rcnt_tl              68817 non-null  float64
#  52  mort_acc                    68817 non-null  float64
#  53  mths_since_recent_bc        68817 non-null  float64
#  54  mths_since_recent_inq       68817 non-null  float64
#  55  num_accts_ever_120_pd       68817 non-null  float64
#  56  num_actv_bc_tl              68817 non-null  float64
#  57  num_actv_rev_tl             68817 non-null  float64
#  58  num_bc_sats                 68817 non-null  float64
#  59  num_bc_tl                   68817 non-null  float64
#  60  num_il_tl                   68817 non-null  float64
#  61  num_op_rev_tl               68817 non-null  float64
#  62  num_rev_accts               68817 non-null  float64
#  63  num_rev_tl_bal_gt_0         68817 non-null  float64
#  64  num_sats                    68817 non-null  float64
#  65  num_tl_120dpd_2m            68817 non-null  float64
#  66  num_tl_30dpd                68817 non-null  float64
#  67  num_tl_90g_dpd_24m          68817 non-null  float64
#  68  num_tl_op_past_12m          68817 non-null  float64
#  69  pct_tl_nvr_dlq              68817 non-null  float64
#  70  percent_bc_gt_75            68817 non-null  float64
#  71  pub_rec_bankruptcies        68817 non-null  float64
#  72  tax_liens                   68817 non-null  float64
#  73  tot_hi_cred_lim             68817 non-null  float64
#  74  total_bal_ex_mort           68817 non-null  float64
#  75  total_bc_limit              68817 non-null  float64
#  76  total_il_high_credit_limit  68817 non-null  float64
#  77  issue_year                  68817 non-null  int32
#  78  next_pymnt_year             68817 non-null  int32
#  79  issue_month_num             68817 non-null  int64
#  80  next_pymnt_month_num        68817 non-null  int64
#  81  home_ownership_le           68817 non-null  int32
#  82  verification_status_le      68817 non-null  int32
#  83  pymnt_plan_le               68817 non-null  int32
#  84  initial_list_status_le      68817 non-null  int32
#  85  application_type_le         68817 non-null  int32
#  86  hardship_flag_le            68817 non-null  int32
#  87  debt_settlement_flag_le     68817 non-null  int32
# dtypes: float64(76), int32(9), int64(2), object(1)
# memory usage: 43.8+ MB

# %% [markdown]
# ### Initial Data Cleaning Assessment
#
# The feature data is ready to split into testing and training sets, scaled and then passed to modelling

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = df.copy()

# Dropping homeowner and loan_statis columns
X.drop(["loan_status"], axis=1, inplace=True)

# Create our target
y = df["loan_status"]

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  next_pymnt_year  issue_month_num  \
# count   68817.000000  ...          68817.0     68817.000000
# mean    17604.142828  ...           2019.0         1.726172
# std     21835.880400  ...              0.0         0.743862
# min         0.000000  ...           2019.0         1.000000
# 25%      6293.000000  ...           2019.0         1.000000
# 50%     12068.000000  ...           2019.0         2.000000
# 75%     21735.000000  ...           2019.0         2.000000
# max    587191.000000  ...           2019.0         3.000000
#
#        next_pymnt_month_num  home_ownership_le  verification_status_le  \
# count          68817.000000       68817.000000            68817.000000
# mean               4.616839           1.812779                0.669994
# std                0.486161           0.941313                0.719105
# min                4.000000           0.000000                0.000000
# 25%                4.000000           1.000000                0.000000
# 50%                5.000000           1.000000                1.000000
# 75%                5.000000           3.000000                1.000000
# max                5.000000           3.000000                2.000000
#
#        pymnt_plan_le  initial_list_status_le  application_type_le  \
# count        68817.0            68817.000000         68817.000000
# mean             0.0                0.876121             0.139660
# std              0.0                0.329446             0.346637
# min              0.0                0.000000             0.000000
# 25%              0.0                1.000000             0.000000
# 50%              0.0                1.000000             0.000000
# 75%              0.0                1.000000             0.000000
# max              0.0                1.000000             1.000000
#
#        hardship_flag_le  debt_settlement_flag_le
# count           68817.0                  68817.0
# mean                0.0                      0.0
# std                 0.0                      0.0
# min                 0.0                      0.0
# 25%                 0.0                      0.0
# 50%                 0.0                      0.0
# 75%                 0.0                      0.0
# max                 0.0                      0.0
#
# [8 rows x 87 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
# Split the X and y into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test= train_test_split(X, 
                                                   y, 
                                                   random_state=1, 
                                                   stratify=y)
# Examine X and y testing and training set shapes
#X_train.shape
#X_test.shape
#y_train.shape
y_test.shape
# Out:
# (17205,)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
X_scaler = scaler.fit(X_train)

# %%
# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
brf_model = RandomForestClassifier(n_estimators=100, random_state=1)
brf_model.fit(X_train_scaled, y_train)
y_pred = brf_model.predict(X_test_scaled)
brf_model
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.6663745764692137

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   29,    58],
#        [   10, 17108]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred, digits=16))
# Out:
#                         pre       rec       spe        f1       geo       iba       sup
#
#        high_risk  0.7435897435897436 0.3333333333333333 0.9994158196050941 0.4603174603174603 0.5771816061994971 0.3109488274036350        87
#         low_risk  0.9966212280088547 0.9994158196050941 0.3333333333333333 0.9980165674950415 0.5771816061994971 0.3553283856664278     17118
#
#      avg / total  0.9953417314006325 0.9960476605637896 0.3367014923746378 0.9952976007804556 0.5771816061994972 0.3551039729045060     17205

# %%
# List the features sorted in descending order by feature importance
importances = brf_model.feature_importances_
sorted(zip(brf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.09103494104659202, 'total_rec_prncp'),
#  (0.07100785388726943, 'total_rec_int'),
#  (0.06648847235067998, 'total_pymnt'),
#  (0.05895125860033097, 'last_pymnt_amnt'),
#  (0.054815748726515026, 'total_pymnt_inv'),
#  (0.0219652225585143, 'out_prncp_inv'),
#  (0.01924753732244239, 'dti'),
#  (0.019034097371012238, 'installment'),
#  (0.018465077520802183, 'out_prncp'),
#  (0.01714900701212202, 'mo_sin_old_rev_tl_op'),
#  (0.016186386811046737, 'loan_amnt'),
#  (0.01572972566926636, 'bc_open_to_buy'),
#  (0.0155364837490489, 'mo_sin_old_il_acct'),
#  (0.015196420504958882, 'max_bal_bc'),
#  (0.015135665999943737, 'revol_bal'),
#  (0.014587558276528419, 'total_rec_late_fee'),
#  (0.014290545902401981, 'tot_cur_bal'),
#  (0.014160603228495303, 'tot_hi_cred_lim'),
#  (0.01390340710073431, 'total_bal_ex_mort'),
#  (0.013767942958685562, 'issue_month_num'),
#  (0.013574456472400636, 'bc_util'),
#  (0.013287291026414176, 'annual_inc'),
#  (0.01325607659054017, 'avg_cur_bal'),
#  (0.01317326110408159, 'total_bc_limit'),
#  (0.01294727425113566, 'total_bal_il'),
#  (0.012566403991256218, 'total_rev_hi_lim'),
#  (0.012080668604134336, 'il_util'),
#  (0.011792704917124721, 'mths_since_rcnt_il'),
#  (0.011775113180294198, 'int_rate'),
#  (0.01153022782130743, 'total_il_high_credit_limit'),
#  (0.011026851719164992, 'all_util'),
#  (0.0109979974420976, 'total_acc'),
#  (0.010585230764976993, 'num_rev_tl_bal_gt_0'),
#  (0.0101722960779918, 'mo_sin_rcnt_rev_tl_op'),
#  (0.009893541912560576, 'num_actv_rev_tl'),
#  (0.009690155492130221, 'num_rev_accts'),
#  (0.009671085874860236, 'mths_since_recent_bc'),
#  (0.009566612286340535, 'num_actv_bc_tl'),
#  (0.00956390106579759, 'open_acc'),
#  (0.009160716837209287, 'mths_since_recent_inq'),
#  (0.009112881210710811, 'num_il_tl'),
#  (0.008894108978841585, 'num_sats'),
#  (0.00883001204150269, 'pct_tl_nvr_dlq'),
#  (0.008723193016831826, 'mo_sin_rcnt_tl'),
#  (0.008471710039305809, 'total_cu_tl'),
#  (0.008256192975392733, 'num_bc_tl'),
#  (0.008140251898037245, 'inq_last_12m'),
#  (0.007815429538875995, 'acc_open_past_24mths'),
#  (0.007779676625379222, 'num_op_rev_tl'),
#  (0.007279707365489965, 'inq_fi'),
#  (0.0071979106025763994, 'percent_bc_gt_75'),
#  (0.007070768918680973, 'open_acc_6m'),
#  (0.0067897986301232805, 'open_act_il'),
#  (0.006695125132926252, 'open_il_24m'),
#  (0.006629590962370957, 'num_bc_sats'),
#  (0.006478981735645943, 'open_rv_24m'),
#  (0.006189950307306596, 'mort_acc'),
#  (0.005686499845474915, 'num_tl_op_past_12m'),
#  (0.00547279507456797, 'inq_last_6mths'),
#  (0.005140312890536824, 'open_rv_12m'),
#  (0.004697440480134893, 'open_il_12m'),
#  (0.004518393549812015, 'home_ownership_le'),
#  (0.004299300958780666, 'num_accts_ever_120_pd'),
#  (0.004187735395598002, 'verification_status_le'),
#  (0.0037459286552211386, 'tot_coll_amt'),
#  (0.0037033312228185967, 'next_pymnt_month_num'),
#  (0.0032059250910901303, 'delinq_2yrs'),
#  (0.0025146624428335784, 'pub_rec'),
#  (0.002493829350864748, 'application_type_le'),
#  (0.0022249603546174264, 'pub_rec_bankruptcies'),
#  (0.0017638192469904316, 'initial_list_status_le'),
#  (0.001670025188827147, 'num_tl_90g_dpd_24m'),
#  (0.0009785091413562776, 'collections_12_mths_ex_med'),
#  (0.0003754171012672564, 'chargeoff_within_12_mths'),
#  (0.0, 'tax_liens'),
#  (0.0, 'recoveries'),
#  (0.0, 'pymnt_plan_le'),
#  (0.0, 'policy_code'),
#  (0.0, 'num_tl_30dpd'),
#  (0.0, 'num_tl_120dpd_2m'),
#  (0.0, 'next_pymnt_year'),
#  (0.0, 'issue_year'),
#  (0.0, 'hardship_flag_le'),
#  (0.0, 'delinq_amnt'),
#  (0.0, 'debt_settlement_flag_le'),
#  (0.0, 'collection_recovery_fee'),
#  (0.0, 'acc_now_delinq')]

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
ee_model = EasyEnsembleClassifier(n_estimators=100, random_state=1)
ee_model.fit(X_train_scaled, y_train)
y_pred = ee_model.predict(X_test_scaled)
ee_model
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9324304724609305

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   80,     7],
#        [  936, 16182]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred, digits=16))
# Out:
#                         pre       rec       spe        f1       geo       iba       sup
#
#        high_risk  0.0787401574803150 0.9195402298850575 0.9453207150368034 0.1450589301903898 0.9323413686091855 0.8670194320653232        87
#         low_risk  0.9995676076348138 0.9453207150368034 0.9195402298850575 0.9716876332302520 0.9323413686091855 0.8715014231747749     17118
#
#      avg / total  0.9949112874858199 0.9451903516419645 0.9196705932798962 0.9675076450195883 0.9323413686091855 0.8714787592267061     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#     - 0.6663745764692137 - Balanced Random Forest Classifier
#     - **0.9324304724609305 - Easy Ensemble Classifier**
#
#     **ANSWER:** Examining the figures above it can bee seen that the **Easy Ensemble Classifier** model had the best balanced accuracy score.
#
# 2. Which model had the best recall score?
#
#     - **0.9960476605637896 - Balanced Random Forest Classifier**
#     - 0.9451903516419645 - Easy Ensemble Classifier
#
#     **ANSWER:** Examining the figures above it can bee seen that the **Balanced Random Forest Classifier** model had the best recall score.
#
# 3. Which model had the best geometric mean score?
#
#     - 0.5771816061994972 - Balanced Random Forest Classifier
#     - **0.9323413686091855 - Easy Ensemble Classifier**
#
#     **ANSWER:** Examining the figures above it can bee seen that the **Easy Ensemble Classifier** model had the best geometric mean score.
#
# 4. What are the top three features?
#
#      **ANSWER:** The following lists the top three features
#          - 0.09103494104659202, 'total_rec_prncp'
#          - 0.07100785388726943, 'total_rec_int'
#          - 0.06648847235067998, 'total_pymnt'
